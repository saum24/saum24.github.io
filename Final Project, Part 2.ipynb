# %% [markdown]
# ## World Resource Trade Analysis

# %% [markdown]
# ### Saumya Pallav

# %% [markdown]
# I have created a dashboard for the dataset "resourcetradeearth-all-all-all-2018.xlsx" which can be found here https://resourcetrade.earth/data.
#
# The data is open source and available to all.
#
# ***File Name:*** resourcetradeearth-all-all-all-2018.xlsx (24.1 Mb)
#
# ***Source:*** Chatham House (2018), ‘resourcetrade.earth’, http://resourcetrade.earth/
#
# ### Dashboard
#
# The dataset is a repository of bilateral trade in natural resources between more than 200 countries and territories for the period 2014 to 2018. It includes the monetary values and masses of trade in over 1,350 different types of natural resources and resource products, including agricultural, fishery and forestry products, fossil fuels, metals and other minerals, and pearls and gemstones.
#
# I have included the data present in the "Trades" sheet of the spreadsheet for analysis.
#
# The dashboard has three parts.
#
# The first part of the dashboard consists of a visualization where the user has the option to select an exporter and year from a dropdown list to generate a plot that details the export value break up across different resource categories. The plot will be a bar plot and the user has the liberty to choose the size of the plot. Also, the default exporter and year will be 'United States' and '2014' when the plot is generated for the first time.
#
# The second part of the dasboard is a visualization where again the user has the option to select an exporter and year from a dropdown list, but this time the plot will be a comparison of resource export for the exporter for different import regions. The plot again will be a bar plot with options to resize. This time, the default exporter and year will be 'Switzerland' and '2016' when the plot is generated the first time.
#
# Finally the third part of the dashboard consists of a visualizatoin where the user has the option to select year from a dropdown list. This will generate a line plot that shows a trend analysis for the top three exporters, based on the total export value, in the selected year across different resource categories. The default year in this case will be '2018' and the user will again have the option to resize the plot.

# %% [markdown]
# ## Visualization Contents
#
#
# [World Resource Trade Exploratory Dashboard](#World-Resource-Trade-Exploratory-Dashboard)
#
# - [Dataframe columns](#Dataframe-columns)
#
# - [Exporter List with their respective instance count](#Exporter-List-with-their-respective-instance-count)
#
# - [Exploratory visualizations for dashboard](#Exploratory-visualizations-for-dashboard)
#
# [Interactive Dashboard](#Interactive-Dashboard)
#
# - [Dashboard Viz 1: Export value break up across different resource categories for an Exporter in a given year](#Dashboard-Viz-1:-Export-value-break-up-across-different-resource-categories-for-an-Exporter-in-a-given-year)
#
# - [Dashboard Viz 2: Resource export comparison of an exporter for different import regions](#Dashboard-Viz-2:-Resource-export-comparison-of-an-exporter-for-different-import-regions)
#
# - [Dashboard Viz 3: Trend analysis for top three exporters over the years](#Dashboard-Viz-3:-Trend-analysis-for-top-three-exporters-over-the-years)

# %% [markdown]
# ## World Resource Trade Exploratory Dashboard

# %%
#Importing the libraries and packages
#Reading the data

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

file_name ="C:/Users/iamsa/OneDrive/Documents/UIUC/Spring 20/DV/Final Proj/resourcetradeearth-all-all-all-2018.xlsx"
sheet = "Trades" 


df = pd.read_excel(io=file_name, sheet_name=sheet)
# print(df.head(5))

# %%
import ipywidgets
from ipywidgets import interact, interactive

# %%
df #Dataframe
# Out:
#         Exporter M.49 Exporter ISO3     Exporter Exporter region  \
# 0                   4           AFG  Afghanistan      South Asia
# 1                   4           AFG  Afghanistan      South Asia
# 2                   4           AFG  Afghanistan      South Asia
# 3                   4           AFG  Afghanistan      South Asia
# 4                   4           AFG  Afghanistan      South Asia
# 5                   4           AFG  Afghanistan      South Asia
# 6                   4           AFG  Afghanistan      South Asia
# 7                   4           AFG  Afghanistan      South Asia
# 8                   4           AFG  Afghanistan      South Asia
# 9                   4           AFG  Afghanistan      South Asia
# 10                  4           AFG  Afghanistan      South Asia
# 11                  4           AFG  Afghanistan      South Asia
# 12                  4           AFG  Afghanistan      South Asia
# ...

# %%
# Row and column count
df.shape
# Out:
# (332444, 14)

# %% [markdown]
# ### Dataframe columns

# %%
# column names and the respective non null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332444 entries, 0 to 332443
# Data columns (total 14 columns):
# Exporter M.49               332444 non-null int64
# Exporter ISO3               326426 non-null object
# Exporter                    332444 non-null object
# Exporter region             332444 non-null object
# Importer M.49               332444 non-null int64
# Importer ISO3               326968 non-null object
# Importer                    332444 non-null object
# Importer region             332444 non-null object
# Resource                    332444 non-null object
# Year                        332444 non-null int64
# Value (1000USD)             316634 non-null float64
# Weight (1000kg)             315700 non-null float64
# Embodied land (ha)          2095 non-null float64
# Embodied blue water (m³)    746 non-null float64
# dtypes: float64(4), int64(3), object(7)
# memory usage: 35.5+ MB

# %% [markdown]
# There are in total 14 columns with different data types.

# %% [markdown]
# ### Exporter List with their respective instance count

# %%
# Exporter countries and territories

df["Exporter"].value_counts().sort_index()
# Out:
# Afghanistan                           714
# Albania                              1022
# Algeria                              1353
# American Samoa                        212
# Andorra                               387
# Angola                               1084
# Anguilla                               99
# Antarctica                             81
# Antigua and Barbuda                   536
# Areas, nes                           1453
# Argentina                            2124
# Armenia                               777
# Aruba                                 336
# Australia                            3706
# Austria                              3829
# Azerbaijan                           1099
# Bahamas                               541
# Bahrain                              1508
# Bangladesh                           1023
# Barbados                              723
# Belarus                              2235
# Belgium                              4952
# ...

# %%
df["Exporter"].value_counts().sum()
# Out:
# 332444

# %% [markdown]
# There are 245 different exporting countries and territories in the dataset with different instances. The sum of instances for the exporters matches the total record count in the dataset.

# %% [markdown]
# ### Exploratory visualizations for dashboard

# %% [markdown]
# For initial analysis, I am considering 'Afghanistan' as the exporter to carry out the analysis. As evident below, 'Afghanistan' exported five different types of natural resources during the period 2014 to 2018.

# %%
# df[(df["Exporter"]=="Afghanistan") & (df["Importer"]=="Argentina")]
df[df["Exporter"]=="Afghanistan"]["Resource"].value_counts().sort_index()
# Out:
# Agricultural products    376
# Fertilizers                6
# Forestry products         29
# Fossil fuels              48
# Metals and minerals      133
# Pearls and gemstones     122
# Name: Resource, dtype: int64

# %% [markdown]
# Afghanistan's bar plot of export values for different resources and their corresponding values.

# %%
df[df["Exporter"]=="Afghanistan"].groupby("Resource")["Value (1000USD)"].sum()
# Out:
# Resource
# Agricultural products    3.857994e+06
# Fertilizers              6.234500e+01
# Forestry products        2.648535e+03
# Fossil fuels             3.763160e+05
# Metals and minerals      8.534559e+05
# Pearls and gemstones     6.430984e+04
# Name: Value (1000USD), dtype: float64

# %%
df[df["Exporter"]=="Afghanistan"].groupby("Resource")["Value (1000USD)"].sum().plot(kind='bar',figsize=(10.0,8.0))

plt.xlabel('Resource Name')
plt.ylabel('Value in 1000 USD')
plt.title("Afghanistan's Export Value (in 1000USD) by Resources")
plt.style.use('ggplot')

# %% [markdown]
# United Kingdom's exported resource distribution for different import regions during the period 2014 to 2018.

# %%
df[df["Exporter"]=="United Kingdom"].groupby(["Importer region","Resource"])["Resource"].count().unstack().plot(kind='bar',figsize=(10.0,8.0))
plt.xlabel('Importer Region')
plt.ylabel('Resource Count')
plt.title("United Kingdom's Resource Export by Import region ")
plt.style.use('ggplot')

# %% [markdown]
# Trend analysis for the top three exporters, based on the total export value, over the years across different resource categories plotted in a line graph. The same plots will be generated by the dasboard in the later section.

# %%
df_tmp1=df[df["Year"]==2014].groupby(["Exporter"])["Value (1000USD)"].sum().sort_values(ascending=False).head(3).index
df_tmp1

df_tmp2=df[df["Year"]==2015].groupby(["Exporter"])["Value (1000USD)"].sum().sort_values(ascending=False).head(3).index
df_tmp2

df_tmp3=df[df["Year"]==2016].groupby(["Exporter"])["Value (1000USD)"].sum().sort_values(ascending=False).head(3).index
df_tmp3

df_tmp4=df[df["Year"]==2017].groupby(["Exporter"])["Value (1000USD)"].sum().sort_values(ascending=False).head(3).index
df_tmp4

df_tmp5=df[df["Year"]==2018].groupby(["Exporter"])["Value (1000USD)"].sum().sort_values(ascending=False).head(3).index
df_tmp5
# Out:
# Index(['United States', 'Russian Federation', 'United Arab Emirates'], dtype='object', name='Exporter')

# %% [markdown]
# Trend analysis for Year 2014

# %%
df[(df["Exporter"]==df_tmp1[0])].groupby("Resource")["Value (1000USD)"].sum().plot(kind='line',label=df_tmp1[0],figsize=(10,10),lw=0.5,marker = '*')
df[(df["Exporter"]==df_tmp1[1])].groupby("Resource")["Value (1000USD)"].sum().plot(kind='line',label=df_tmp1[1],figsize=(10,10),lw=0.5,marker = '*')
df[(df["Exporter"]==df_tmp1[2])].groupby("Resource")["Value (1000USD)"].sum().plot(kind='line',label=df_tmp1[2],figsize=(10,10),lw=0.5,marker = '*')
plt.xlabel('Resource Name')
plt.ylabel('Value in 1000 USD')
plt.title("Top 3 Countries' Export Value (in 1000USD) by Resources in 2014")
plt.grid(True)
plt.legend()

# %% [markdown]
# Trend analysis for Year 2015

# %%
df[(df["Exporter"]==df_tmp2[0])].groupby("Resource")["Value (1000USD)"].sum().plot(kind='line',label=df_tmp2[0],figsize=(10,10),lw=0.5,marker = '*')
df[(df["Exporter"]==df_tmp2[1])].groupby("Resource")["Value (1000USD)"].sum().plot(kind='line',label=df_tmp2[1],figsize=(10,10),lw=0.5,marker = '*')
df[(df["Exporter"]==df_tmp2[2])].groupby("Resource")["Value (1000USD)"].sum().plot(kind='line',label=df_tmp2[2],figsize=(10,10),lw=0.5,marker = '*')
plt.xlabel('Resource Name')
plt.ylabel('Value in 1000 USD')
plt.title("Top 3 Countries' Export Value (in 1000USD) by Resources in 2015")
plt.grid(True)
plt.legend()

# %% [markdown]
# Trend analysis for Year 2016

# %%
df[(df["Exporter"]==df_tmp3[0])].groupby("Resource")["Value (1000USD)"].sum().plot(kind='line',label=df_tmp3[0],figsize=(10,10),lw=0.5,marker = '*')
df[(df["Exporter"]==df_tmp3[1])].groupby("Resource")["Value (1000USD)"].sum().plot(kind='line',label=df_tmp3[1],figsize=(10,10),lw=0.5,marker = '*')
df[(df["Exporter"]==df_tmp3[2])].groupby("Resource")["Value (1000USD)"].sum().plot(kind='line',label=df_tmp3[2],figsize=(10,10),lw=0.5,marker = '*')
plt.xlabel('Resource Name')
plt.ylabel('Value in 1000 USD')
plt.title("Top 3 Countries' Export Value (in 1000USD) by Resources in 2016")
plt.grid(True)
plt.legend()

# %% [markdown]
# Trend analysis for Year 2017

# %%
df[(df["Exporter"]==df_tmp4[0])].groupby("Resource")["Value (1000USD)"].sum().plot(kind='line',label=df_tmp4[0],figsize=(10,10),lw=0.5,marker = '*')
df[(df["Exporter"]==df_tmp4[1])].groupby("Resource")["Value (1000USD)"].sum().plot(kind='line',label=df_tmp4[1],figsize=(10,10),lw=0.5,marker = '*')
df[(df["Exporter"]==df_tmp4[2])].groupby("Resource")["Value (1000USD)"].sum().plot(kind='line',label=df_tmp4[2],figsize=(10,10),lw=0.5,marker = '*')
plt.xlabel('Resource Name')
plt.ylabel('Value in 1000 USD')
plt.title("Top 3 Countries' Export Value (in 1000USD) by Resources in 2017")
plt.grid(True)
plt.legend()

# %% [markdown]
# Trend analysis for Year 2018

# %%
df[(df["Exporter"]==df_tmp5[0])].groupby("Resource")["Value (1000USD)"].sum().plot(kind='line',label=df_tmp5[0],figsize=(10,10),lw=0.5,marker = '*')
df[(df["Exporter"]==df_tmp5[1])].groupby("Resource")["Value (1000USD)"].sum().plot(kind='line',label=df_tmp5[1],figsize=(10,10),lw=0.5,marker = '*')
df[(df["Exporter"]==df_tmp5[2])].groupby("Resource")["Value (1000USD)"].sum().plot(kind='line',label=df_tmp5[2],figsize=(10,10),lw=0.5,marker = '*')
plt.xlabel('Resource Name')
plt.ylabel('Value in 1000 USD')
plt.title("Top 3 Countries' Export Value (in 1000USD) by Resources in 2018")
plt.grid(True)
plt.legend()

# %% [markdown]
# ## Interactive Dashboard

# %% [markdown]
# ### Dashboard Viz 1: Export value break up across different resource categories for an Exporter in a given year
#
# The default exporter is United States when the plot is generated for the first time.

# %%
@ipywidgets.interact(exporter = df.Exporter.unique(),year=df.Year.unique(),width=[5,8,10,12,15], height=[5,8,10,12,15])
def plot(exporter='United States',year=2014,width=5, height=5):
    df[(df["Exporter"]==exporter) & (df["Year"]==year)].groupby("Resource")["Value (1000USD)"].sum().plot(kind='bar',figsize=(width,height))
    plt.xlabel('Resource Name')
    plt.ylabel('Value in 1000 USD')
    plt.title(exporter+"'s Export Value (in 1000USD) by Resources")
    plt.style.use('ggplot')
# Out:
# interactive(children=(Dropdown(description='exporter', index=235, options=('Afghanistan', 'Albania', 'Antarcti…

# %% [markdown]
# ### Dashboard Viz 2: Resource export comparison of an exporter for different import regions
#
# An exporter's exported resource distribution for different import regions in a selected year.
#
# The default exporter and year is Switzerland and 2016 when the plot is generated for the very first time.

# %%
@ipywidgets.interact(exporter = df.Exporter.unique(),year=df.Year.unique(), width=[5,8,10,12,15], height=[5,8,10,12,15])
def plot(exporter='Switzerland',year=2016, width=5, height=5):
    df[(df["Exporter"]==exporter)&(df.Year==year)].groupby(["Importer region","Resource"])["Resource"].count().unstack().plot(kind='bar',figsize=(width,height))
    plt.xlabel('Importer Region')
    plt.ylabel('Resource Count')
    plt.title(exporter+"'s Resource Export by Import region ")
    plt.style.use('ggplot')
# Out:
# interactive(children=(Dropdown(description='exporter', index=212, options=('Afghanistan', 'Albania', 'Antarcti…

# %% [markdown]
# ### Dashboard Viz 3: Trend analysis for top three exporters over the years
#
# Trend analysis for the top three exporters, based on the total export value, in the selected year across different resource categories plotted in a line graph.
#
# The default year is 2018 when the plot is generated for the first time.

# %%
@ipywidgets.interact(year=df.Year.unique(),width=[5,8,10,12,15], height=[5,8,10,12,15])
def plot(year=2018,width=15, height=10):
    df_tmp=df[df["Year"]==year].groupby(["Exporter"])["Value (1000USD)"].sum().sort_values(ascending=False).head(3).index
    df[(df["Exporter"]==df_tmp[0])].groupby("Resource")["Value (1000USD)"].sum().plot(kind='line',label=df_tmp[0],figsize=(width,height),lw=0.5,marker = '*')
    df[(df["Exporter"]==df_tmp[1])].groupby("Resource")["Value (1000USD)"].sum().plot(kind='line',label=df_tmp[1],figsize=(width,height),lw=0.5,marker = '*')
    df[(df["Exporter"]==df_tmp[2])].groupby("Resource")["Value (1000USD)"].sum().plot(kind='line',label=df_tmp[2],figsize=(width,height),lw=0.5,marker = '*')
    plt.xlabel('Resource Name')
    plt.ylabel('Value in 1000 USD')
    plt.title("Top 3 Countries' Export Value (in 1000USD) by Resources in a given year")
    plt.grid(True)
    plt.legend()
# Out:
# interactive(children=(Dropdown(description='year', index=4, options=(2014, 2015, 2016, 2017, 2018), value=2018…
